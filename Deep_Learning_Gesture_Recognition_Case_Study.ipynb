# %% [markdown]
# ### Submitted By:
# ##### 1. Gursewak Singh
# ##### 2. Bharat Bhushan
# ##### 3. Himanshu Yadav

# %% [markdown]
# # Deep Learning Gesture Recognition
# In this group project, we are going to build a 3D Conv model that will be able to predict the 5 gestures correctly.

# %% [markdown]
# ### Problem Statement
# Imagine you are working as a data scientist at a home electronics company which manufactures state of the art smart televisions. You want to develop a cool feature in the smart-TV that can recognise five different gestures performed by the user which will help users control the TV without using a remote.
#
# The gestures are continuously monitored by the webcam mounted on the TV. Each gesture corresponds to a specific command:
#
# | Gesture | Corresponding Action |
# | --- | --- |
# | Thumbs Up | Increase the volume. |
# | Thumbs Down | Decrease the volume. |
# | Left Swipe | 'Jump' backwards 10 seconds. |
# | Right Swipe | 'Jump' forward 10 seconds. |
# | Stop | Pause the movie. |
#
# Each video is a sequence of 30 frames (or images).
#
# ### Objectives:
# 1. **Generator**:  The generator should be able to take a batch of videos as input without any error. Steps like cropping, resizing and normalization should be performed successfully.
#
# 2. **Model**: Develop a model that is able to train without any errors which will be judged on the total number of parameters (as the inference(prediction) time should be less) and the accuracy achieved. As suggested by Snehansu, start training on a small amount of data and then proceed further.
#
# 3. **Write up**: This should contain the detailed procedure followed in choosing the final model. The write up should start with the reason for choosing the base model, then highlight the reasons and metrics taken into consideration to modify and experiment to arrive at the final model.

# %%
import numpy as np
import os
# from scipy.misc import imread, imresize
from imageio import imread
import datetime
import os
from PIL import Image, ImageFilter, ImageEnhance

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
np.random.seed(30)

import random as rn
rn.seed(30)
from keras import backend as K
import matplotlib.pyplot as plt
import tensorflow as tf
from skimage.transform import resize
tf.random.set_seed(30)

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %%
def get_data(path, ablation=None):
    train_doc = np.random.permutation(open(path+'train.csv').readlines())
    val_doc = np.random.permutation(open(path+'val.csv').readlines())
    counts = np.zeros(5) # count for loading folders for 5 classes
    train_data = []
    val_data = []
    # when ablation is None pass full training and val data
    if ablation is not None:
        # iterating train doc
        for doc in train_doc:
            lable = int(doc.strip().split(';')[2])
            if counts[lable] < ablation:
                train_data.append(doc)
                counts[lable] += 1
        counts = np.zeros(5)
        # iterating val doc
        for doc in val_doc:
            lable = int(doc.strip().split(';')[2])
            if counts[lable] < ablation:
                val_data.append(doc)
                counts[lable] += 1
    else:
        train_data, val_data = train_doc, val_doc
    return train_data, val_data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# base path of the data
base_path = "/content/drive/MyDrive"
project_folder = "Project_data"
source_path = base_path+"/"+project_folder

#traning data csv path
train_data_csv_path = source_path + '/train.csv'
val_data_csv_path = source_path + '/val.csv'

base_path = "/content/drive/MyDrive"
project_folder = "Project_data"
source_path = base_path+"/"+project_folder + "/"

train_doc, val_doc = get_data(source_path, ablation=None)
batch_size = 32 # experiment with the batch size
enable_augmentation = False # augmentation of Data
# sequence ids
# selecting alternate frames from 7 to 26.
seq_idx = range(6,26,2)
# image dimensions
x_dim, y_dim = 120, 120

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
def generator(source_path, folder_list, batch_size, is_train = False, augmention = False, debug=False):
    # print('\nSource path = ', source_path, '; batch size =', batch_size)
    img_idx = seq_idx #create a list of image numbers you want to use for a particular video
    x = len(img_idx)
    y, z = x_dim, y_dim
    while True:
        # doubling the data for augmentation
        if is_train and augmention:
            t = np.concatenate((np.random.permutation(folder_list), np.random.permutation(folder_list)))
        else:
            t = np.random.permutation(folder_list)

        if (len(t)%batch_size) == 0:
            num_batches = int(len(t)/batch_size)
        else:
            num_batches = len(t)//batch_size + 1

        for batch in range(num_batches): # we iterate over the number of batches
            batch_data = np.zeros((batch_size,x,y,z,3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterate over the batch_size
                if debug:
                    plt.figure(figsize=(20,5))
                #handling remaining datapoints
                folder_idx = folder + (batch*batch_size)
                if folder_idx >= len(t):
                    break
                folder_str = t[folder_idx]
                imgs = os.listdir(source_path+'/'+ folder_str.split(';')[0]) # read all the images in the folder
                # randomly enabling augmentation and augmentation type
                aug_type = None
                if is_train and augmention and rn.randint(0,1) == 1:
                    aug_type = rn.randint(0, 4) #randomly selecting augmentation type
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ folder_str.strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)

                    # plotting original images for debugging purpose only
                    if debug:
                        plt.subplot(2, x, idx+1)
                        plt.imshow(image.astype('uint8'))

                    #crop the images and resize them. Note that the images are of 2 different shape
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    # making the rectangle images into square by cropping sides
                    # so the aspect ration can be mantained while resizing.
                    if image.shape[1] > image.shape[0]:
                        diff_px = image.shape[1] - image.shape[0]
                        crop_start = diff_px//2
                        crop_end = crop_start + image.shape[0]
                        image = image[:, crop_start:crop_end]
                    elif image.shape[0] > image.shape[1]:
                        diff_px = image.shape[0] - image.shape[1]
                        crop_start = diff_px//2
                        crop_end = crop_start + image.shape[1]
                        image = image[:, crop_start:crop_end]

                    resized_im = resize(image,(y,z,3))

                    if aug_type is not None:
                        if aug_type == 0: # edge Enhancement
                            resized_im = np.array(Image.fromarray(resized_im, 'RGB').filter(ImageFilter.EDGE_ENHANCE))
                        elif aug_type == 1: # adding gaussian blur
                            resized_im = np.array(Image.fromarray(resized_im, 'RGB').filter(ImageFilter.GaussianBlur(1)))
                        elif aug_type == 2: # enchancing image detailing
                            resized_im = np.array(Image.fromarray(resized_im, 'RGB').filter(ImageFilter.DETAIL))
                        elif aug_type == 3: # sharpening image
                            resized_im = np.array(Image.fromarray(resized_im, 'RGB').filter(ImageFilter.SHARPEN))
                        elif aug_type == 4: # Brightness enhancement
                            resized_im = np.array(ImageEnhance.Brightness((Image.fromarray(resized_im, 'RGB'))).enhance(1.5))
                    # plotting rezised images for debugging purpose only
                    if debug:
                        plt.subplot(2, x, idx+x+1)
                        plt.imshow(image.astype('uint8'))

                    batch_data[folder,idx,:,:,0] = resized_im[:,:,0]/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = resized_im[:,:,1]/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = resized_im[:,:,2]/255 #normalise and feed in the image

                batch_labels[folder, int(folder_str.strip().split(';')[2])] = 1
            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %%
curr_dt_time = datetime.datetime.now()
train_path = source_path+"/train"
val_path = source_path+"/val"
# train_path = '/notebooks/storage/Final_data/Collated_training/train'
# val_path = '/notebooks/storage/Final_data/Collated_training/val'

#multiply number train seq by 2 when using augmentation
multiplier = 1
if enable_augmentation:
    multiplier = 2
num_train_sequences = len(train_doc)*multiplier
print('# training sequences =', num_train_sequences)

num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)


###################################
##  choose the number of epochs  ##
###################################
num_epochs = 50 # choose the number of epochs
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 50

# %%
# testing generative
test_gen = generator(train_path, train_doc, 1, is_train = True, augmention = True, debug = True)
d = next(test_gen)[0]
# Out:
# <ipython-input-32-be1d3b5c060b>:35: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(source_path+'/'+ folder_str.strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)

# %%
# analysing the images in a folder
img_path = os.listdir(train_path+"/"+train_doc[9].split(";")[0])[29]
image = imread(train_path+"/"+train_doc[9].split(";")[0] +"/"+img_path)
resized_image = resize(image,(120,120))
plt.subplot(1, 1,1)
plt.imshow(resized_image)
# Out:
# <ipython-input-35-2b3d065b9f6e>:3: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(train_path+"/"+train_doc[9].split(";")[0] +"/"+img_path)

# %% [markdown]
# ## Model
# Here you make the model using different functionalities that Keras provides. Remember to use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. You would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation, Dropout, Conv2D, MaxPooling2D, LSTM, GlobalAveragePooling3D, ConvLSTM2D, GlobalAveragePooling2D
from tensorflow.keras.layers  import Conv3D, MaxPooling3D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras import optimizers

#write your model here
input_shape = (len(seq_idx), x_dim, y_dim, 3)
np.random.seed(30)

# %% [markdown]
# ### Experiment - 1,2,3 and 4
# **Conv3D**

# %%
# model = Sequential()
# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(MaxPooling3D(pool_size=2))

# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=2))

# model.add(Flatten())
# model.add(Dense(256, activation='relu'))
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment - 5
# **Conv3D**

# %%
# model = Sequential()

# model.add(Conv3D(32, kernel_size=3, activation='relu',padding="same", input_shape=input_shape))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))

# model.add(Conv3D(128, kernel_size=3, activation='relu',padding="same"))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))

# model.add(Conv3D(256, kernel_size=(3, 3, 3), activation='relu',padding="same"))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))

# model.add(Conv3D(512, kernel_size=(3, 3, 3), activation='relu',padding="same"))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))

# model.add(Flatten())
# model.add(Dense(512, activation='relu'))
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment - 6
# **Conv3D**

# %%
# model = Sequential()

# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))
# model.add(BatchNormalization())

# model.add(Conv3D(128, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())

# model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())

# model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
# model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())

# model.add(Flatten())
# model.add(Dense(512, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment - 7
# **Conv3D**

# %%
# model = Sequential()

# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))
# model.add(BatchNormalization())
# model.add(Dropout(0.5))

# model.add(Conv3D(128, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# model.add(Dropout(0.5))

# model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# model.add(Dropout(0.5))

# model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
# model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# model.add(Dropout(0.5))

# model.add(Flatten())
# model.add(Dense(512, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment - 8
# **Conv3D**

# %%
# model = Sequential()

# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))
# model.add(BatchNormalization())
# model.add(Dropout(0.5))

# model.add(Conv3D(128, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# model.add(Dropout(0.5))

# model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# model.add(Dropout(0.5))

# model.add(GlobalAveragePooling3D())
# model.add(Dense(512, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment - 9
# **Conv3D with Data Augmentation**

# %%
# model = Sequential()

# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))
# model.add(BatchNormalization())
# model.add(Dropout(0.5))

# model.add(Conv3D(128, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# model.add(Dropout(0.5))

# model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# model.add(Dropout(0.5))

# model.add(GlobalAveragePooling3D())
# model.add(Dense(512, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment - 10
# **TimeDistributed + ConvLSTM2D**

# %%
# model = Sequential()
# model.add(TimeDistributed(
#     Conv2D(8, (3,3), activation='relu'), input_shape=input_shape)
# )
# model.add(BatchNormalization())
# model.add(TimeDistributed(
#     Conv2D(16, (3,3), activation='relu'))
# )
# model.add(BatchNormalization())
# model.add(
#     ConvLSTM2D(8, kernel_size = 3, return_sequences=False)
# )
# model.add(BatchNormalization())
# model.add(TimeDistributed(
#     Dense(64, activation='relu'))
# )
# model.add(BatchNormalization())
# model.add(GlobalAveragePooling2D())
# model.add(Dense(64, activation='relu'))
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment - 11
# **CNN+LSTM**

# %%
# model = Sequential()

# model.add(TimeDistributed(Conv2D(16, (3, 3) , padding='same', activation='relu'),
#                           input_shape=input_shape))
# model.add(TimeDistributed(BatchNormalization()))
# model.add(TimeDistributed(MaxPooling2D((2, 2))))

# model.add(TimeDistributed(Conv2D(32, (3, 3) , padding='same', activation='relu')))
# model.add(TimeDistributed(BatchNormalization()))
# model.add(TimeDistributed(MaxPooling2D((2, 2))))

# model.add(TimeDistributed(Conv2D(64, (3, 3) , padding='same', activation='relu')))
# model.add(TimeDistributed(BatchNormalization()))
# model.add(TimeDistributed(MaxPooling2D((2, 2))))

# model.add(TimeDistributed(Conv2D(128, (3, 3) , padding='same', activation='relu')))
# model.add(TimeDistributed(BatchNormalization()))
# model.add(TimeDistributed(MaxPooling2D((2, 2))))

# model.add(TimeDistributed(Conv2D(256, (3, 3) , padding='same', activation='relu')))
# model.add(TimeDistributed(BatchNormalization()))
# model.add(TimeDistributed(MaxPooling2D((2, 2))))

# model.add(TimeDistributed(Flatten()))


# model.add(LSTM(64))
# model.add(Dropout(0.25))

# model.add(Dense(64,activation='relu'))
# model.add(Dropout(0.25))

# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Final Model
# ##### After doing all the experiments, we finalized Model 11 - CNN+LSTM, which performed well.
#
# __Reason:__
#
# - Training Accuracy : 0.9777 , Validation Accuracy : 0.8203
#
# - Number of trainable Parameters (1,004,549) with size 3.83 MB
#
# - Total trainable parameters (1,005,541) with size 3.84 MB
#
# - The best weights of CNN-LSTM: model-00048-0.04068-0.97768-0.62349-0.82031.h5 (11.6 MB).

# %%
model = Sequential()

model.add(TimeDistributed(Conv2D(16, (3, 3) , padding='same', activation='relu'),
                          input_shape=input_shape))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(MaxPooling2D((2, 2))))

model.add(TimeDistributed(Conv2D(32, (3, 3) , padding='same', activation='relu')))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(MaxPooling2D((2, 2))))

model.add(TimeDistributed(Conv2D(64, (3, 3) , padding='same', activation='relu')))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(MaxPooling2D((2, 2))))

model.add(TimeDistributed(Conv2D(128, (3, 3) , padding='same', activation='relu')))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(MaxPooling2D((2, 2))))

model.add(TimeDistributed(Conv2D(256, (3, 3) , padding='same', activation='relu')))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(MaxPooling2D((2, 2))))

model.add(TimeDistributed(Flatten()))


model.add(LSTM(64))
model.add(Dropout(0.25))

model.add(Dense(64,activation='relu'))
model.add(Dropout(0.25))

model.add(Dense(5, activation='softmax'))

# %% [markdown]
# Now that you have written the model, the next step is to `compile` the model. When you print the `summary` of the model, you'll see the total number of parameters you have to train.

# %%
optimiser = optimizers.Adam(lr=0.01) #write your optimizer
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model.summary())
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_21 (TimeD  (None, 10, 120, 120, 16   448
#  istributed)                 )
#
#  time_distributed_22 (TimeD  (None, 10, 120, 120, 16   64
#  istributed)                 )
#
#  time_distributed_23 (TimeD  (None, 10, 60, 60, 16)    0
#  istributed)
#
#  time_distributed_24 (TimeD  (None, 10, 60, 60, 32)    4640
#  istributed)
#
#  time_distributed_25 (TimeD  (None, 10, 60, 60, 32)    128
#  istributed)
#
#  time_distributed_26 (TimeD  (None, 10, 30, 30, 32)    0
#  istributed)
#
#  time_distributed_27 (TimeD  (None, 10, 30, 30, 64)    18496
#  istributed)
#
#  time_distributed_28 (TimeD  (None, 10, 30, 30, 64)    256
#  istributed)
#
#  time_distributed_29 (TimeD  (None, 10, 15, 15, 64)    0
#  istributed)
#
#  time_distributed_30 (TimeD  (None, 10, 15, 15, 128)   73856
#  istributed)
#
#  time_distributed_31 (TimeD  (None, 10, 15, 15, 128)   512
#  istributed)
#
#  time_distributed_32 (TimeD  (None, 10, 7, 7, 128)     0
#  istributed)
#
#  time_distributed_33 (TimeD  (None, 10, 7, 7, 256)     295168
#  istributed)
#
#  time_distributed_34 (TimeD  (None, 10, 7, 7, 256)     1024
#  istributed)
#
#  time_distributed_35 (TimeD  (None, 10, 3, 3, 256)     0
#  istributed)
#
#  time_distributed_36 (TimeD  (None, 10, 2304)          0
#  istributed)
#
#  lstm_1 (LSTM)               (None, 64)                606464
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 64)                4160
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_6 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 1005541 (3.84 MB)
# Trainable params: 1004549 (3.83 MB)
# Non-trainable params: 992 (3.88 KB)
# _________________________________________________________________
# None

# %% [markdown]
# Let us create the `train_generator` and the `val_generator` which will be used in `.fit_generator`.

# %%
train_generator = generator(train_path, train_doc, batch_size, is_train = True, augmention = enable_augmentation)
val_generator = generator(val_path, val_doc, batch_size)

# %%
model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'

if not os.path.exists(model_name):
    os.mkdir(model_name)

filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)

# write the REducelronplateau code here
LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.001, verbose=1)
callbacks_list = [checkpoint, LR]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %% [markdown]
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
model_history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
                        callbacks=callbacks_list, validation_data=val_generator,
                        validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# <ipython-input-50-39784564f3ba>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model_history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
# <ipython-input-32-be1d3b5c060b>:35: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(source_path+'/'+ folder_str.strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# Epoch 1/50
# 21/21 [==============================] - ETA: 0s - loss: 1.4573 - categorical_accuracy: 0.3348
# Epoch 1: saving model to model_init_2023-10-3002_17_02.295172/model-00001-1.45733-0.33482-1.32136-0.14062.h5
# 21/21 [==============================] - 88s 4s/step - loss: 1.4573 - categorical_accuracy: 0.3348 - val_loss: 1.3214 - val_categorical_accuracy: 0.1406 - lr: 0.0010
# Epoch 2/50
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 21/21 [==============================] - ETA: 0s - loss: 1.2231 - categorical_accuracy: 0.4762
# Epoch 2: saving model to model_init_2023-10-3002_17_02.295172/model-00002-1.22311-0.47619-1.45808-0.14062.h5
# 21/21 [==============================] - 82s 4s/step - loss: 1.2231 - categorical_accuracy: 0.4762 - val_loss: 1.4581 - val_categorical_accuracy: 0.1406 - lr: 0.0010
# Epoch 3/50
# 21/21 [==============================] - ETA: 0s - loss: 1.0457 - categorical_accuracy: 0.5744
# Epoch 3: saving model to model_init_2023-10-3002_17_02.295172/model-00003-1.04567-0.57440-1.50935-0.14062.h5
# 21/21 [==============================] - 73s 4s/step - loss: 1.0457 - categorical_accuracy: 0.5744 - val_loss: 1.5093 - val_categorical_accuracy: 0.1406 - lr: 0.0010
# Epoch 4/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9259 - categorical_accuracy: 0.6295
# Epoch 4: saving model to model_init_2023-10-3002_17_02.295172/model-00004-0.92593-0.62946-1.44084-0.17188.h5
# 21/21 [==============================] - 71s 4s/step - loss: 0.9259 - categorical_accuracy: 0.6295 - val_loss: 1.4408 - val_categorical_accuracy: 0.1719 - lr: 0.0010
# Epoch 5/50
# 21/21 [==============================] - ETA: 0s - loss: 0.8333 - categorical_accuracy: 0.6667
# Epoch 5: saving model to model_init_2023-10-3002_17_02.295172/model-00005-0.83333-0.66667-1.36738-0.25000.h5
# 21/21 [==============================] - 76s 4s/step - loss: 0.8333 - categorical_accuracy: 0.6667 - val_loss: 1.3674 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 6/50
# 21/21 [==============================] - ETA: 0s - loss: 0.7339 - categorical_accuracy: 0.7128
# Epoch 6: saving model to model_init_2023-10-3002_17_02.295172/model-00006-0.73386-0.71280-1.66794-0.24219.h5
# 21/21 [==============================] - 74s 4s/step - loss: 0.7339 - categorical_accuracy: 0.7128 - val_loss: 1.6679 - val_categorical_accuracy: 0.2422 - lr: 0.0010
# Epoch 7/50
# 21/21 [==============================] - ETA: 0s - loss: 0.6790 - categorical_accuracy: 0.7381
# Epoch 7: saving model to model_init_2023-10-3002_17_02.295172/model-00007-0.67898-0.73810-1.71275-0.21875.h5
# 21/21 [==============================] - 75s 4s/step - loss: 0.6790 - categorical_accuracy: 0.7381 - val_loss: 1.7128 - val_categorical_accuracy: 0.2188 - lr: 0.0010
# Epoch 8/50
# 21/21 [==============================] - ETA: 0s - loss: 0.6463 - categorical_accuracy: 0.7574
# Epoch 8: saving model to model_init_2023-10-3002_17_02.295172/model-00008-0.64632-0.75744-1.92817-0.25781.h5
# 21/21 [==============================] - 71s 4s/step - loss: 0.6463 - categorical_accuracy: 0.7574 - val_loss: 1.9282 - val_categorical_accuracy: 0.2578 - lr: 0.0010
# Epoch 9/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5248 - categorical_accuracy: 0.8065
# Epoch 9: saving model to model_init_2023-10-3002_17_02.295172/model-00009-0.52476-0.80655-1.85298-0.20312.h5
# 21/21 [==============================] - 76s 4s/step - loss: 0.5248 - categorical_accuracy: 0.8065 - val_loss: 1.8530 - val_categorical_accuracy: 0.2031 - lr: 0.0010
# Epoch 10/50
# 21/21 [==============================] - ETA: 0s - loss: 0.4397 - categorical_accuracy: 0.8363
# Epoch 10: saving model to model_init_2023-10-3002_17_02.295172/model-00010-0.43968-0.83631-1.66234-0.24219.h5
# 21/21 [==============================] - 76s 4s/step - loss: 0.4397 - categorical_accuracy: 0.8363 - val_loss: 1.6623 - val_categorical_accuracy: 0.2422 - lr: 0.0010
# Epoch 11/50
# 21/21 [==============================] - ETA: 0s - loss: 0.3822 - categorical_accuracy: 0.8542
# Epoch 11: saving model to model_init_2023-10-3002_17_02.295172/model-00011-0.38216-0.85417-1.96712-0.18750.h5
# 21/21 [==============================] - 75s 4s/step - loss: 0.3822 - categorical_accuracy: 0.8542 - val_loss: 1.9671 - val_categorical_accuracy: 0.1875 - lr: 0.0010
# Epoch 12/50
# 21/21 [==============================] - ETA: 0s - loss: 0.4255 - categorical_accuracy: 0.8393
# Epoch 12: saving model to model_init_2023-10-3002_17_02.295172/model-00012-0.42548-0.83929-1.99224-0.17969.h5
# 21/21 [==============================] - 71s 4s/step - loss: 0.4255 - categorical_accuracy: 0.8393 - val_loss: 1.9922 - val_categorical_accuracy: 0.1797 - lr: 0.0010
# Epoch 13/50
# 21/21 [==============================] - ETA: 0s - loss: 0.3689 - categorical_accuracy: 0.8512
# Epoch 13: saving model to model_init_2023-10-3002_17_02.295172/model-00013-0.36886-0.85119-1.33617-0.28125.h5
# 21/21 [==============================] - 74s 4s/step - loss: 0.3689 - categorical_accuracy: 0.8512 - val_loss: 1.3362 - val_categorical_accuracy: 0.2812 - lr: 0.0010
# Epoch 14/50
# 21/21 [==============================] - ETA: 0s - loss: 0.3266 - categorical_accuracy: 0.8884
# Epoch 14: saving model to model_init_2023-10-3002_17_02.295172/model-00014-0.32665-0.88839-2.12548-0.21875.h5
# 21/21 [==============================] - 74s 4s/step - loss: 0.3266 - categorical_accuracy: 0.8884 - val_loss: 2.1255 - val_categorical_accuracy: 0.2188 - lr: 0.0010
# Epoch 15/50
# 21/21 [==============================] - ETA: 0s - loss: 0.2431 - categorical_accuracy: 0.9122
# Epoch 15: saving model to model_init_2023-10-3002_17_02.295172/model-00015-0.24310-0.91220-1.85036-0.23438.h5
# 21/21 [==============================] - 74s 4s/step - loss: 0.2431 - categorical_accuracy: 0.9122 - val_loss: 1.8504 - val_categorical_accuracy: 0.2344 - lr: 0.0010
# Epoch 16/50
# 21/21 [==============================] - ETA: 0s - loss: 0.2235 - categorical_accuracy: 0.9167
# Epoch 16: saving model to model_init_2023-10-3002_17_02.295172/model-00016-0.22351-0.91667-1.79649-0.27344.h5
# 21/21 [==============================] - 69s 3s/step - loss: 0.2235 - categorical_accuracy: 0.9167 - val_loss: 1.7965 - val_categorical_accuracy: 0.2734 - lr: 0.0010
# Epoch 17/50
# 21/21 [==============================] - ETA: 0s - loss: 0.2149 - categorical_accuracy: 0.9226
# Epoch 17: saving model to model_init_2023-10-3002_17_02.295172/model-00017-0.21492-0.92262-1.22655-0.44531.h5
# 21/21 [==============================] - 78s 4s/step - loss: 0.2149 - categorical_accuracy: 0.9226 - val_loss: 1.2266 - val_categorical_accuracy: 0.4453 - lr: 0.0010
# Epoch 18/50
# 21/21 [==============================] - ETA: 0s - loss: 0.2610 - categorical_accuracy: 0.9062
# Epoch 18: saving model to model_init_2023-10-3002_17_02.295172/model-00018-0.26099-0.90625-2.23005-0.25000.h5
# 21/21 [==============================] - 78s 4s/step - loss: 0.2610 - categorical_accuracy: 0.9062 - val_loss: 2.2300 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 19/50
# 21/21 [==============================] - ETA: 0s - loss: 0.2330 - categorical_accuracy: 0.9062
# Epoch 19: saving model to model_init_2023-10-3002_17_02.295172/model-00019-0.23297-0.90625-1.73383-0.25781.h5
# 21/21 [==============================] - 76s 4s/step - loss: 0.2330 - categorical_accuracy: 0.9062 - val_loss: 1.7338 - val_categorical_accuracy: 0.2578 - lr: 0.0010
# Epoch 20/50
# 21/21 [==============================] - ETA: 0s - loss: 0.1913 - categorical_accuracy: 0.9286
# Epoch 20: saving model to model_init_2023-10-3002_17_02.295172/model-00020-0.19135-0.92857-1.52894-0.33594.h5
# 21/21 [==============================] - 71s 4s/step - loss: 0.1913 - categorical_accuracy: 0.9286 - val_loss: 1.5289 - val_categorical_accuracy: 0.3359 - lr: 0.0010
# Epoch 21/50
# 21/21 [==============================] - ETA: 0s - loss: 0.1864 - categorical_accuracy: 0.9315
# Epoch 21: saving model to model_init_2023-10-3002_17_02.295172/model-00021-0.18638-0.93155-1.45733-0.63281.h5
# 21/21 [==============================] - 80s 4s/step - loss: 0.1864 - categorical_accuracy: 0.9315 - val_loss: 1.4573 - val_categorical_accuracy: 0.6328 - lr: 0.0010
# Epoch 22/50
# 21/21 [==============================] - ETA: 0s - loss: 0.1420 - categorical_accuracy: 0.9464
# Epoch 22: saving model to model_init_2023-10-3002_17_02.295172/model-00022-0.14195-0.94643-0.97658-0.47656.h5
# 21/21 [==============================] - 76s 4s/step - loss: 0.1420 - categorical_accuracy: 0.9464 - val_loss: 0.9766 - val_categorical_accuracy: 0.4766 - lr: 0.0010
# Epoch 23/50
# 21/21 [==============================] - ETA: 0s - loss: 0.0997 - categorical_accuracy: 0.9643
# Epoch 23: saving model to model_init_2023-10-3002_17_02.295172/model-00023-0.09971-0.96429-1.17802-0.64844.h5
# 21/21 [==============================] - 77s 4s/step - loss: 0.0997 - categorical_accuracy: 0.9643 - val_loss: 1.1780 - val_categorical_accuracy: 0.6484 - lr: 0.0010
# Epoch 24/50
# 21/21 [==============================] - ETA: 0s - loss: 0.1086 - categorical_accuracy: 0.9568
# Epoch 24: saving model to model_init_2023-10-3002_17_02.295172/model-00024-0.10858-0.95685-1.29604-0.63281.h5
# 21/21 [==============================] - 70s 4s/step - loss: 0.1086 - categorical_accuracy: 0.9568 - val_loss: 1.2960 - val_categorical_accuracy: 0.6328 - lr: 0.0010
# Epoch 25/50
# 21/21 [==============================] - ETA: 0s - loss: 0.0874 - categorical_accuracy: 0.9583
# Epoch 25: saving model to model_init_2023-10-3002_17_02.295172/model-00025-0.08744-0.95833-1.47855-0.59375.h5
# 21/21 [==============================] - 76s 4s/step - loss: 0.0874 - categorical_accuracy: 0.9583 - val_loss: 1.4786 - val_categorical_accuracy: 0.5938 - lr: 0.0010
# Epoch 26/50
# 21/21 [==============================] - ETA: 0s - loss: 0.0547 - categorical_accuracy: 0.9762
# Epoch 26: saving model to model_init_2023-10-3002_17_02.295172/model-00026-0.05472-0.97619-1.20863-0.67188.h5
# 21/21 [==============================] - 74s 4s/step - loss: 0.0547 - categorical_accuracy: 0.9762 - val_loss: 1.2086 - val_categorical_accuracy: 0.6719 - lr: 0.0010
# Epoch 27/50
# 21/21 [==============================] - ETA: 0s - loss: 0.0545 - categorical_accuracy: 0.9762
# Epoch 27: saving model to model_init_2023-10-3002_17_02.295172/model-00027-0.05452-0.97619-1.47202-0.65625.h5
# 21/21 [==============================] - 74s 4s/step - loss: 0.0545 - categorical_accuracy: 0.9762 - val_loss: 1.4720 - val_categorical_accuracy: 0.6562 - lr: 0.0010
# Epoch 28/50
# 21/21 [==============================] - ETA: 0s - loss: 0.0498 - categorical_accuracy: 0.9792
# Epoch 28: saving model to model_init_2023-10-3002_17_02.295172/model-00028-0.04982-0.97917-0.75841-0.79688.h5
# 21/21 [==============================] - 70s 3s/step - loss: 0.0498 - categorical_accuracy: 0.9792 - val_loss: 0.7584 - val_categorical_accuracy: 0.7969 - lr: 0.0010
# Epoch 29/50
# 21/21 [==============================] - ETA: 0s - loss: 0.0448 - categorical_accuracy: 0.9792
# Epoch 29: saving model to model_init_2023-10-3002_17_02.295172/model-00029-0.04480-0.97917-1.05014-0.50781.h5
# 21/21 [==============================] - 77s 4s/step - loss: 0.0448 - categorical_accuracy: 0.9792 - val_loss: 1.0501 - val_categorical_accuracy: 0.5078 - lr: 0.0010
# Epoch 30/50
# 21/21 [==============================] - ETA: 0s - loss: 0.0560 - categorical_accuracy: 0.9628
# Epoch 30: saving model to model_init_2023-10-3002_17_02.295172/model-00030-0.05604-0.96280-1.70373-0.42188.h5
# 21/21 [==============================] - 76s 4s/step - loss: 0.0560 - categorical_accuracy: 0.9628 - val_loss: 1.7037 - val_categorical_accuracy: 0.4219 - lr: 0.0010
# Epoch 31/50
# 21/21 [==============================] - ETA: 0s - loss: 0.0449 - categorical_accuracy: 0.9747
# Epoch 31: saving model to model_init_2023-10-3002_17_02.295172/model-00031-0.04487-0.97470-1.11221-0.57812.h5
# 21/21 [==============================] - 74s 4s/step - loss: 0.0449 - categorical_accuracy: 0.9747 - val_loss: 1.1122 - val_categorical_accuracy: 0.5781 - lr: 0.0010
# Epoch 32/50
# 21/21 [==============================] - ETA: 0s - loss: 0.0429 - categorical_accuracy: 0.9762
# Epoch 32: saving model to model_init_2023-10-3002_17_02.295172/model-00032-0.04291-0.97619-1.22827-0.53906.h5
# 21/21 [==============================] - 71s 4s/step - loss: 0.0429 - categorical_accuracy: 0.9762 - val_loss: 1.2283 - val_categorical_accuracy: 0.5391 - lr: 0.0010
# Epoch 33/50
# 21/21 [==============================] - ETA: 0s - loss: 0.0297 - categorical_accuracy: 0.9821
# Epoch 33: saving model to model_init_2023-10-3002_17_02.295172/model-00033-0.02966-0.98214-0.75764-0.79688.h5
# 21/21 [==============================] - 73s 4s/step - loss: 0.0297 - categorical_accuracy: 0.9821 - val_loss: 0.7576 - val_categorical_accuracy: 0.7969 - lr: 0.0010
# Epoch 34/50
# 21/21 [==============================] - ETA: 0s - loss: 0.0267 - categorical_accuracy: 0.9866
# Epoch 34: saving model to model_init_2023-10-3002_17_02.295172/model-00034-0.02668-0.98661-0.73973-0.82812.h5
# 21/21 [==============================] - 75s 4s/step - loss: 0.0267 - categorical_accuracy: 0.9866 - val_loss: 0.7397 - val_categorical_accuracy: 0.8281 - lr: 0.0010
# Epoch 35/50
# 21/21 [==============================] - ETA: 0s - loss: 0.0492 - categorical_accuracy: 0.9702
# Epoch 35: saving model to model_init_2023-10-3002_17_02.295172/model-00035-0.04917-0.97024-1.41579-0.50781.h5
# 21/21 [==============================] - 72s 4s/step - loss: 0.0492 - categorical_accuracy: 0.9702 - val_loss: 1.4158 - val_categorical_accuracy: 0.5078 - lr: 0.0010
# Epoch 36/50
# 21/21 [==============================] - ETA: 0s - loss: 0.1178 - categorical_accuracy: 0.9435
# Epoch 36: saving model to model_init_2023-10-3002_17_02.295172/model-00036-0.11783-0.94345-1.80222-0.38281.h5
# 21/21 [==============================] - 69s 3s/step - loss: 0.1178 - categorical_accuracy: 0.9435 - val_loss: 1.8022 - val_categorical_accuracy: 0.3828 - lr: 0.0010
# Epoch 37/50
# 21/21 [==============================] - ETA: 0s - loss: 0.1592 - categorical_accuracy: 0.9330
# Epoch 37: saving model to model_init_2023-10-3002_17_02.295172/model-00037-0.15924-0.93304-0.94126-0.51562.h5
# 21/21 [==============================] - 80s 4s/step - loss: 0.1592 - categorical_accuracy: 0.9330 - val_loss: 0.9413 - val_categorical_accuracy: 0.5156 - lr: 0.0010
# Epoch 38/50
# 21/21 [==============================] - ETA: 0s - loss: 0.1541 - categorical_accuracy: 0.9405
# Epoch 38: saving model to model_init_2023-10-3002_17_02.295172/model-00038-0.15409-0.94048-1.03651-0.44531.h5
# 21/21 [==============================] - 75s 4s/step - loss: 0.1541 - categorical_accuracy: 0.9405 - val_loss: 1.0365 - val_categorical_accuracy: 0.4453 - lr: 0.0010
# Epoch 39/50
# 21/21 [==============================] - ETA: 0s - loss: 0.1068 - categorical_accuracy: 0.9554
# Epoch 39: saving model to model_init_2023-10-3002_17_02.295172/model-00039-0.10681-0.95536-0.98876-0.50781.h5
# 21/21 [==============================] - 73s 4s/step - loss: 0.1068 - categorical_accuracy: 0.9554 - val_loss: 0.9888 - val_categorical_accuracy: 0.5078 - lr: 0.0010
# Epoch 40/50
# 21/21 [==============================] - ETA: 0s - loss: 0.1879 - categorical_accuracy: 0.9301
# Epoch 40: saving model to model_init_2023-10-3002_17_02.295172/model-00040-0.18787-0.93006-0.97088-0.53125.h5
# 21/21 [==============================] - 72s 4s/step - loss: 0.1879 - categorical_accuracy: 0.9301 - val_loss: 0.9709 - val_categorical_accuracy: 0.5312 - lr: 0.0010
# Epoch 41/50
# 21/21 [==============================] - ETA: 0s - loss: 0.1663 - categorical_accuracy: 0.9390
# Epoch 41: saving model to model_init_2023-10-3002_17_02.295172/model-00041-0.16635-0.93899-0.83725-0.71875.h5
# 21/21 [==============================] - 74s 4s/step - loss: 0.1663 - categorical_accuracy: 0.9390 - val_loss: 0.8372 - val_categorical_accuracy: 0.7188 - lr: 0.0010
# Epoch 42/50
# 21/21 [==============================] - ETA: 0s - loss: 0.1908 - categorical_accuracy: 0.9211
# Epoch 42: saving model to model_init_2023-10-3002_17_02.295172/model-00042-0.19085-0.92113-0.97672-0.78125.h5
# 21/21 [==============================] - 74s 4s/step - loss: 0.1908 - categorical_accuracy: 0.9211 - val_loss: 0.9767 - val_categorical_accuracy: 0.7812 - lr: 0.0010
# Epoch 43/50
# 21/21 [==============================] - ETA: 0s - loss: 0.1771 - categorical_accuracy: 0.9271
# Epoch 43: saving model to model_init_2023-10-3002_17_02.295172/model-00043-0.17710-0.92708-0.77874-0.80469.h5
# 21/21 [==============================] - 74s 4s/step - loss: 0.1771 - categorical_accuracy: 0.9271 - val_loss: 0.7787 - val_categorical_accuracy: 0.8047 - lr: 0.0010
# Epoch 44/50
# 21/21 [==============================] - ETA: 0s - loss: 0.1214 - categorical_accuracy: 0.9464
# Epoch 44: saving model to model_init_2023-10-3002_17_02.295172/model-00044-0.12141-0.94643-1.66894-0.28906.h5
# 21/21 [==============================] - 70s 3s/step - loss: 0.1214 - categorical_accuracy: 0.9464 - val_loss: 1.6689 - val_categorical_accuracy: 0.2891 - lr: 0.0010
# Epoch 45/50
# 21/21 [==============================] - ETA: 0s - loss: 0.0787 - categorical_accuracy: 0.9702
# Epoch 45: saving model to model_init_2023-10-3002_17_02.295172/model-00045-0.07873-0.97024-0.83318-0.77344.h5
# 21/21 [==============================] - 78s 4s/step - loss: 0.0787 - categorical_accuracy: 0.9702 - val_loss: 0.8332 - val_categorical_accuracy: 0.7734 - lr: 0.0010
# Epoch 46/50
# 21/21 [==============================] - ETA: 0s - loss: 0.0473 - categorical_accuracy: 0.9821
# Epoch 46: saving model to model_init_2023-10-3002_17_02.295172/model-00046-0.04726-0.98214-0.79369-0.82031.h5
# 21/21 [==============================] - 74s 4s/step - loss: 0.0473 - categorical_accuracy: 0.9821 - val_loss: 0.7937 - val_categorical_accuracy: 0.8203 - lr: 0.0010
# Epoch 47/50
# 21/21 [==============================] - ETA: 0s - loss: 0.0709 - categorical_accuracy: 0.9673
# Epoch 47: saving model to model_init_2023-10-3002_17_02.295172/model-00047-0.07089-0.96726-0.69478-0.63281.h5
# 21/21 [==============================] - 74s 4s/step - loss: 0.0709 - categorical_accuracy: 0.9673 - val_loss: 0.6948 - val_categorical_accuracy: 0.6328 - lr: 0.0010
# Epoch 48/50
# 21/21 [==============================] - ETA: 0s - loss: 0.0407 - categorical_accuracy: 0.9777
# Epoch 48: saving model to model_init_2023-10-3002_17_02.295172/model-00048-0.04068-0.97768-0.62349-0.82031.h5
# 21/21 [==============================] - 71s 4s/step - loss: 0.0407 - categorical_accuracy: 0.9777 - val_loss: 0.6235 - val_categorical_accuracy: 0.8203 - lr: 0.0010
# Epoch 49/50
# 21/21 [==============================] - ETA: 0s - loss: 0.0512 - categorical_accuracy: 0.9747
# Epoch 49: saving model to model_init_2023-10-3002_17_02.295172/model-00049-0.05122-0.97470-0.73394-0.62500.h5
# 21/21 [==============================] - 75s 4s/step - loss: 0.0512 - categorical_accuracy: 0.9747 - val_loss: 0.7339 - val_categorical_accuracy: 0.6250 - lr: 0.0010
# Epoch 50/50
# 21/21 [==============================] - ETA: 0s - loss: 0.0484 - categorical_accuracy: 0.9777
# Epoch 50: saving model to model_init_2023-10-3002_17_02.295172/model-00050-0.04840-0.97768-0.78674-0.59375.h5
# 21/21 [==============================] - 74s 4s/step - loss: 0.0484 - categorical_accuracy: 0.9777 - val_loss: 0.7867 - val_categorical_accuracy: 0.5938 - lr: 0.0010

# %%
plt.figure(figsize=(20,6))
ax1 = plt.subplot(121)
ax1 = plt.plot(model_history.history['loss'])
ax1 = plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower left')
ax2 = plt.subplot(122)
ax2 = plt.plot(model_history.history['categorical_accuracy'])
ax2 = plt.plot(model_history.history['val_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('categorical_accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower left')
